# %%
'''
FIRST VERSION - VERBOSE

A SIMPLE PYTHON CALCULATOR using input, nested if-else statements and lists

INPUT:
- two numbers, from the user
- the numbers must be either integers or a floating point numbers
- in case of division, divisor cannot be 0
- the user has to select the operation to be performed


OUTPUT:
- floating point number
'''

#please tell us your name (optional)
print('Welcome to this simple Python calculator!')
print('')
print('We would love to know your name!')
print("This is an optional section, so if you do not wish to reveal your name, you may enter '-' in the input box\nand proceed ahead")
print('')

name = input('Please enter your name ')

print('')

if name != '-':
    print(f'Hi {name}!, lovely to have you with us :)')

print('')

#operation selection
print('Please select the number associated with the operation you wish to perform:')
print('')
print('1. Addition')
print('2. Subtraction')
print('3. Multiplication')
print('4. Division')

operation_choice = input('Please enter 1, 2, 3, or 4: ')

print('')

operation_list = ['1','2','3','4']

#OUTER IF-ELSE STATEMENT
if operation_choice not in operation_list:
    operation_choice = input("Your entry isn't valid, please enter a valid input: ")

    #NESTED IF-ELSE STATEMENT (to offer the user a chance to re-enter a correct operation number)
    if operation_choice not in operation_list:
        print('Your entry still is not valid, please start over')

    else:
        # first number from the user
        number_1 = float(input('Please enter the first number: '))
        # second number from the user
        number_2 = float(input('Please enter the second number: '))

        print('')

        if operation_choice == '1':
            answer = number_1 + number_2
            print('Your answer is',answer)

        elif operation_choice == '2':
            answer = number_1 - number_2
            print('Your answer is',answer)

        elif operation_choice == '3':
            answer = number_1 * number_2
            print('Your answer is',answer)

        elif operation_choice == '4':
            # Check if the second number is not zero
            if number_2 == 0:
                number_2 = float(input("Sorry, zero cannot be the divisor! Please enter a different number: "))

                if number_2 == 0:
                    print('Zero cannot be the divisor')
                else:
                    answer = number_1/number_2
                    print('Your answer is',answer)

            else:
                answer = number_1/number_2
                print('Your answer is',answer)


else:
        # first number from the user
        number_1 = float(input('Please enter the first number: '))
        # second number from the user
        number_2 = float(input('Please enter the second number: '))

        print('')

        if operation_choice == '1':
            answer = number_1 + number_2
            print('Your answer is',answer)

        elif operation_choice == '2':
            answer = number_1 - number_2
            print('Your answer is',answer)

        elif operation_choice == '3':
            answer = number_1 * number_2
            print('Your answer is',answer)

        elif operation_choice == '4':
            # Check if the second number is not zero
            if number_2 == 0:
                number_2 = float(input("Sorry, zero cannot be the divisor! Please enter a different number: "))

                if number_2 == 0:
                    print('Zero cannot be the divisor, please start over')
                else:
                    answer = number_1/number_2
                    print('Your answer is',answer)

            else:
                answer = number_1/number_2
                print('Your answer is',answer)

print('\nHave a good day!')
# Out:
# Welcome to this simple Python calculator!
#
# We would love to know your name!
# This is an optional section, so if you do not wish to reveal your name, you may enter '-' in the input box
# and proceed ahead
#
# Please enter your name Ashwin
#
# Hi Ashwin!, lovely to have you with us :)
#
# Please select the number associated with the operation you wish to perform:
#
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Please enter 1, 2, 3, or 4: 4.5
#
# Your entry isn't valid, please enter a valid input: 3423
# Your entry still is not valid, please start over
#
# Have a good day!

# %%
'''
SECOND VERSION - COMPACT

A SIMPLE PYTHON CALCULATOR using input, nested if-else statements and lists

INPUT:
- two numbers, from the user
- the numbers must be either integers or a floating point numbers
- in case of division, divisor cannot be 0
- the user has to select the operation to be performed


OUTPUT:
- floating point number
'''

#please tell us your name (optional)
print('Welcome to this simple Python calculator!')
print('')
print('We would love to know your name!')
print("This is an optional section, so if you do not wish to reveal your name, you may enter '-' in the input box\nand proceed ahead")
print('')

name = input('Please enter your name ')

print('')

if name != '-' and name != "'-'":
    print(f'Hi {name}!, lovely to have you with us :)')

print('')

#operation selection
print('Please select the number associated with the operation you wish to perform:')
print('')
print('1. Addition')
print('2. Subtraction')
print('3. Multiplication')
print('4. Division')

operation_choice = input('Please enter 1, 2, 3, or 4: ')

print('')

operation_list = ['1','2','3','4']

#while loop for repeating operation selection in the event of invalid inputs
while operation_choice not in operation_list:
    operation_choice = input(f"Your entry ({operation_choice}) isn't valid, please enter a valid input: ")


number_1 = float(input('Please enter the first number: '))
        # second number from the user
number_2 = float(input('Please enter the second number: '))

print('')

if operation_choice == '1':
    answer = number_1 + number_2
    print('Your answer is',answer)

elif operation_choice == '2':
    answer = number_1 - number_2
    print('Your answer is',answer)

elif operation_choice == '3':
    answer = number_1 * number_2
    print('Your answer is',answer)

elif operation_choice == '4':
    # Check if the second number is not zero
    while number_2 == 0:
        number_2 = float(input("Sorry, zero cannot be the divisor! Please enter a different number: "))

    answer = number_1/number_2
    print('Your answer is',answer)

print('\nHave a good day!')
# Out:
# Welcome to this simple Python calculator!
#
# We would love to know your name!
# This is an optional section, so if you do not wish to reveal your name, you may enter '-' in the input box
# and proceed ahead
#
# Please enter your name Ashwin
#
# Hi Ashwin!, lovely to have you with us :)
#
# Please select the number associated with the operation you wish to perform:
#
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Please enter 1, 2, 3, or 4: 245
#
# Your entry (245) isn't valid, please enter a valid input: 324
# Your entry (324) isn't valid, please enter a valid input: 3423
# Your entry (3423) isn't valid, please enter a valid input: 4
# Please enter the first number: 32342
# Please enter the second number: 0
#
# Sorry, zero cannot be the divisor! Please enter a different number: 0
# Sorry, zero cannot be the divisor! Please enter a different number: 0
# Sorry, zero cannot be the divisor! Please enter a different number: 687
# Your answer is 47.077147016011644
#
# ...
